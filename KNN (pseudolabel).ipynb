# %%
from csv import reader
from sys import exit
from math import sqrt
from operator import itemgetter


def load_data_set(filename):
    try:
        with open(filename, newline='') as dataset:
            return list(reader(dataset, delimiter=','))
    except FileNotFoundError as e:
        raise e


def convert_to_float(data_set, mode):
    new_set = []
    try:
        if mode == 'training':
            for data in data_set:
                new_set.append([float(x) for x in data[:len(data)-1]] + [data[len(data)-1]])

        elif mode == 'test':
            for data in data_set:
                new_set.append([float(x) for x in data])

        else:
            print('Invalid mode, program will exit.')
            exit()

        return new_set

    except ValueError as v:
        print(v)
        print('Invalid data set format, program will exit.')
        exit()


def get_classes(training_set):
    return list(set([c[-1] for c in training_set]))


def find_neighbors(distances, k):
    return distances[0:k]


def find_response(neighbors, classes):
    votes = [0] * len(classes)

    for instance in neighbors:
        for ctr, c in enumerate(classes):
            if instance[-2] == c:
                votes[ctr] += 1

    return max(enumerate(votes), key=itemgetter(1))


def knn(training_set, test_set, k):
    distances = []
    dist = 0
    limit = len(training_set[0]) - 1

    # generate response classes from training data
    classes = get_classes(training_set)

    try:
        for test_instance in test_set:
            for row in training_set:
                for x, y in zip(row[:limit], test_instance):
                    dist += (x-y) * (x-y)
                distances.append(row + [sqrt(dist)])
                dist = 0

            distances.sort(key=itemgetter(len(distances[0])-1))

            # find k nearest neighbors
            neighbors = find_neighbors(distances, k)

            # get the class with maximum votes
            index, value = find_response(neighbors, classes)

            # Display prediction
            print('The predicted class for sample ' + str(test_instance) + ' is : ' + classes[index])
            print('Number of votes : ' + str(value) + ' out of ' + str(k))

            # empty the distance list
            distances.clear()

    except Exception as e:
        print(e)


def main():
    try:
        # get value of k
        k = int(input('Enter the value of k : '))

        # load the training and test data set
        training_file = input('Enter name of training data file : ')
        test_file = input('Enter name of test data file : ')
        training_set = convert_to_float(load_data_set(training_file), 'training')
        test_set = convert_to_float(load_data_set(test_file), 'test')

        if not training_set:
            print('Empty training set')

        elif not test_set:
            print('Empty test set')

        elif k > len(training_set):
            print('Expected number of neighbors is higher than number of training data instances')

        else:
            knn(training_set, test_set, k)

    except ValueError as v:
        print(v)

    except FileNotFoundError:
        print('File not found')


if __name__ == '__main__':
    main()
# Out:
# Enter the value of k : 3
# Enter name of training data file : datasetlabel.csv
# Enter name of test data file : datasetnolabel.csv
# The predicted class for sample [6.2, 6.2, 6.1] is : Tidak Manis
# Number of votes : 3 out of 3
# The predicted class for sample [5.9, 5.9, 5.7] is : Tidak Manis
# Number of votes : 2 out of 3
# The predicted class for sample [5.9, 6.1, 5.6] is : Tidak Manis
# Number of votes : 2 out of 3
# The predicted class for sample [6.2, 6.8, 7.5] is : Kurang Manis
# Number of votes : 3 out of 3
# The predicted class for sample [6.6, 6.4, 4.6] is : Tidak Manis
# Number of votes : 3 out of 3
# The predicted class for sample [6.1, 6.7, 5.8] is : Kurang Manis
# Number of votes : 2 out of 3
# The predicted class for sample [5.0, 5.6, 5.8] is : Tidak Manis
# Number of votes : 1 out of 3
# The predicted class for sample [2.7, 3.7, 4.6] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [4.0, 4.6, 5.1] is : Manis
# Number of votes : 2 out of 3
# The predicted class for sample [3.4, 4.6, 4.6] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [4.4, 4.8, 4.6] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [5.5, 5.2, 5.1] is : Tidak Manis
# Number of votes : 2 out of 3
# The predicted class for sample [6.5, 6.3, 5.7] is : Tidak Manis
# Number of votes : 3 out of 3
# The predicted class for sample [6.1, 6.1, 5.5] is : Tidak Manis
# Number of votes : 3 out of 3
# The predicted class for sample [6.1, 7.1, 7.2] is : Kurang Manis
# Number of votes : 3 out of 3
# The predicted class for sample [2.5, 3.2, 5.3] is : Manis
# Number of votes : 2 out of 3
# The predicted class for sample [3.4, 4.2, 3.1] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.0, 8.0, 7.7] is : Sangat Manis
# Number of votes : 2 out of 3
# The predicted class for sample [4.1, 3.7, 3.9] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [4.7, 6.0, 6.5] is : Manis
# Number of votes : 1 out of 3
# The predicted class for sample [3.9, 3.8, 4.6] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [4.0, 3.9, 3.5] is : Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.1, 6.6, 8.2] is : Sangat Manis
# Number of votes : 2 out of 3
# The predicted class for sample [7.7, 7.7, 8.5] is : Sangat Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.6, 8.9, 9.8] is : Sangat Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.5, 7.9, 7.7] is : Sangat Manis
# Number of votes : 2 out of 3
# The predicted class for sample [7.3, 8.4, 8.4] is : Sangat Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.7, 8.9, 8.7] is : Sangat Manis
# Number of votes : 3 out of 3
# The predicted class for sample [7.7, 8.0, 8.6] is : Sangat Manis
# Number of votes : 3 out of 3
# The predicted class for sample [8.3, 9.3, 10.7] is : Sangat Manis
# Number of votes : 3 out of 3
